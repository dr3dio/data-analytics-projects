# %%
import pandas as pd
import numpy as np
from sklearn import model_selection
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
df = pd.read_csv('/Users/andreas/Desktop/wgu/d210/telecom_churn.csv') 

df.head()

print(df['Churn'])
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3328    0
# 3329    0
# 3330    0
# 3331    0
# 3332    0
# Name: Churn, Length: 3333, dtype: int64

# %% [markdown]
# <h2>Make churn into dummy</h2>

# %%
df = df.replace(to_replace={'Churn': {1: "Yes", 0: "No"}}, value=None)
print(df['Churn'])
# Out:
# 0       No
# 1       No
# 2       No
# 3       No
# 4       No
#         ..
# 3328    No
# 3329    No
# 3330    No
# 3331    No
# 3332    No
# Name: Churn, Length: 3333, dtype: object

# %%
#export cleaned data
df.to_csv('/Users/andreas/Desktop/wgu/d210/telecom_churn_edited.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Churn            3333 non-null   object
#  1   AccountWeeks     3333 non-null   int64
#  2   ContractRenewal  3333 non-null   int64
#  3   DataPlan         3333 non-null   int64
#  4   DataUsage        3333 non-null   float64
#  5   CustServCalls    3333 non-null   int64
#  6   DayMins          3333 non-null   float64
#  7   DayCalls         3333 non-null   int64
#  8   MonthlyCharge    3333 non-null   float64
#  9   OverageFee       3333 non-null   float64
#  10  RoamMins         3333 non-null   float64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 286.6+ KB

# %%
df1 = pd.read_csv('/Users/andreas/Desktop/wgu/d210/telecom_churn_edited.csv') 
  
df2 = pd.read_csv('/Users/andreas/Desktop/wgu/d210/churn_clean.csv')

# %% [markdown]
# <h2>Concat dataframes into one</h2>

# %%
frames = [df, df2]
  
result = pd.concat(frames)
display(result)
# Out:
#      Churn  AccountWeeks  ContractRenewal  DataPlan  DataUsage  CustServCalls  \
# 0       No         128.0              1.0       1.0        2.7            1.0
# 1       No         107.0              1.0       1.0        3.7            1.0
# 2       No         137.0              1.0       0.0        0.0            0.0
# 3       No          84.0              0.0       0.0        0.0            2.0
# 4       No          75.0              0.0       0.0        0.0            3.0
# ...    ...           ...              ...       ...        ...            ...
# 9995    No           NaN              NaN       NaN        NaN            NaN
# 9996    No           NaN              NaN       NaN        NaN            NaN
# 9997    No           NaN              NaN       NaN        NaN            NaN
# 9998    No           NaN              NaN       NaN        NaN            NaN
# 9999    No           NaN              NaN       NaN        NaN            NaN
#
#       DayMins  DayCalls  MonthlyCharge  OverageFee  ...    Tenure  \
# 0       265.1     110.0        89.0000        9.87  ...       NaN
# 1       161.6     123.0        82.0000        9.78  ...       NaN
# 2       243.4     114.0        52.0000        6.06  ...       NaN
# 3       299.4      71.0        57.0000        3.10  ...       NaN
# 4       166.7     113.0        41.0000        7.42  ...       NaN
# ...       ...       ...            ...         ...  ...       ...
# 9995      NaN       NaN       159.9794         NaN  ...  68.19713
# 9996      NaN       NaN       207.4811         NaN  ...  61.04037
# 9997      NaN       NaN       169.9741         NaN  ...  47.41689
# 9998      NaN       NaN       252.6240         NaN  ...  71.09560
# 9999      NaN       NaN       217.4840         NaN  ...  63.35086
#
#       Bandwidth_GB_Year Item1 Item2 Item3 Item4 Item5 Item6  Item7  Item8
# 0                   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN
# 1                   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN
# 2                   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN
# 3                   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN
# 4                   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN
# ...                 ...   ...   ...   ...   ...   ...   ...    ...    ...
# 9995        6511.252601   3.0   2.0   3.0   3.0   4.0   3.0    2.0    3.0
# 9996        5695.951810   4.0   5.0   5.0   4.0   4.0   5.0    2.0    5.0
# 9997        4159.305799   4.0   4.0   4.0   4.0   4.0   4.0    4.0    5.0
# 9998        6468.456752   4.0   4.0   6.0   4.0   3.0   3.0    5.0    4.0
# 9999        5857.586167   2.0   2.0   3.0   3.0   3.0   3.0    4.0    1.0
#
# [13333 rows x 59 columns]

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13333 entries, 0 to 9999
# Data columns (total 59 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Churn                 13333 non-null  object
#  1   AccountWeeks          3333 non-null   float64
#  2   ContractRenewal       3333 non-null   float64
#  3   DataPlan              3333 non-null   float64
#  4   DataUsage             3333 non-null   float64
#  5   CustServCalls         3333 non-null   float64
#  6   DayMins               3333 non-null   float64
#  7   DayCalls              3333 non-null   float64
#  8   MonthlyCharge         13333 non-null  float64
#  9   OverageFee            3333 non-null   float64
#  10  RoamMins              3333 non-null   float64
#  11  CaseOrder             10000 non-null  float64
#  12  Customer_id           10000 non-null  object
#  13  Interaction           10000 non-null  object
#  14  UID                   10000 non-null  object
#  15  City                  10000 non-null  object
#  16  State                 10000 non-null  object
#  17  County                10000 non-null  object
#  18  Zip                   10000 non-null  float64
#  19  Lat                   10000 non-null  float64
#  20  Lng                   10000 non-null  float64
#  21  Population            10000 non-null  float64
#  22  Area                  10000 non-null  object
#  23  TimeZone              10000 non-null  object
#  24  Job                   10000 non-null  object
#  25  Children              10000 non-null  float64
#  26  Age                   10000 non-null  float64
#  27  Income                10000 non-null  float64
#  28  Marital               10000 non-null  object
#  29  Gender                10000 non-null  object
#  30  Outage_sec_perweek    10000 non-null  float64
#  31  Email                 10000 non-null  float64
#  32  Contacts              10000 non-null  float64
#  33  Yearly_equip_failure  10000 non-null  float64
#  34  Techie                10000 non-null  object
#  35  Contract              10000 non-null  object
#  36  Port_modem            10000 non-null  object
#  37  Tablet                10000 non-null  object
#  38  InternetService       10000 non-null  object
#  39  Phone                 10000 non-null  object
#  40  Multiple              10000 non-null  object
#  41  OnlineSecurity        10000 non-null  object
#  42  OnlineBackup          10000 non-null  object
#  43  DeviceProtection      10000 non-null  object
#  44  TechSupport           10000 non-null  object
#  45  StreamingTV           10000 non-null  object
#  46  StreamingMovies       10000 non-null  object
#  47  PaperlessBilling      10000 non-null  object
#  48  PaymentMethod         10000 non-null  object
#  49  Tenure                10000 non-null  float64
#  50  Bandwidth_GB_Year     10000 non-null  float64
#  51  Item1                 10000 non-null  float64
#  52  Item2                 10000 non-null  float64
#  53  Item3                 10000 non-null  float64
#  54  Item4                 10000 non-null  float64
#  55  Item5                 10000 non-null  float64
#  56  Item6                 10000 non-null  float64
#  57  Item7                 10000 non-null  float64
#  58  Item8                 10000 non-null  float64
# dtypes: float64(32), object(27)
# memory usage: 6.1+ MB

# %%
df_joined = result

# %%
df_joined = df_joined[['Churn', 'MonthlyCharge']]

# %%
df_joined.head()
# Out:
#   Churn  MonthlyCharge
# 0    No           89.0
# 1    No           82.0
# 2    No           52.0
# 3    No           57.0
# 4    No           41.0

# %%
df_joined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13333 entries, 0 to 9999
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Churn          13333 non-null  object
#  1   MonthlyCharge  13333 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 312.5+ KB

# %%
df_joined.info
# Out:
# <bound method DataFrame.info of      Churn  MonthlyCharge
# 0       No        89.0000
# 1       No        82.0000
# 2       No        52.0000
# 3       No        57.0000
# 4       No        41.0000
# ...    ...            ...
# 9995    No       159.9794
# 9996    No       207.4811
# 9997    No       169.9741
# 9998    No       252.6240
# 9999    No       217.4840
#
# [13333 rows x 2 columns]>

# %% [markdown]
# <h2>Export into Tableau</h2>

# %%
df_joined.to_csv('/Users/andreas/Desktop/wgu/d210/joinedchurn.csv')
