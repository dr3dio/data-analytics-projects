# %%
import pandas as pd
from matplotlib import pyplot
import matplotlib.pyplot as plt
import statsmodels as sm
import seaborn as sns
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import statistics
sns.set(rc = {'figure.figsize':(15,8)})

# %%
df = pd.read_csv(r'C:\Users\dre2\Desktop\WGU\D213\set\med.csv', parse_dates=True, squeeze=True)
print(df)
sns.lineplot(x='Day', y='Revenue', legend='full', data=df)
# Out:
#      Day    Revenue
# 0      1   0.000000
# 1      2  -0.292356
# 2      3  -0.327772
# 3      4  -0.339987
# 4      5  -0.124888
# ..   ...        ...
# 726  727  15.722056
# 727  728  15.865822
# 728  729  15.708988
# 729  730  15.822867
# 730  731  16.069429
#
# [731 rows x 2 columns]
# <AxesSubplot:xlabel='Day', ylabel='Revenue'>

# %%
df.describe()
# Out:
#               Day     Revenue
# count  731.000000  731.000000
# mean   366.000000   14.179608
# std    211.165812    6.959905
# min      1.000000   -4.423299
# 25%    183.500000   11.121742
# 50%    366.000000   15.951830
# 75%    548.500000   19.293506
# max    731.000000   24.792249

# %%
df.isnull().any()
# Out:
# Day        False
# Revenue    False
# dtype: bool

# %%
import datetime as dt
from datetime import datetime

day1 = dt.datetime.today()
#must specify 1 day extra to account for Day 0 being index
date_list = [day1 + dt.timedelta(days=x) for x in range(731)]

# %%
df['Date'] = date_list
df.head()
# Out:
#    Day   Revenue                       Date
# 0    1  0.000000 2023-03-08 14:06:28.191284
# 1    2 -0.292356 2023-03-09 14:06:28.191284
# 2    3 -0.327772 2023-03-10 14:06:28.191284
# 3    4 -0.339987 2023-03-11 14:06:28.191284
# 4    5 -0.124888 2023-03-12 14:06:28.191284

# %%
df['Date'] = pd.to_datetime(df['Date']).dt.date

# %%
df.head()
# Out:
#    Day   Revenue        Date
# 0    1  0.000000  2023-03-08
# 1    2 -0.292356  2023-03-09
# 2    3 -0.327772  2023-03-10
# 3    4 -0.339987  2023-03-11
# 4    5 -0.124888  2023-03-12

# %%
#check stationarity of time series
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries, window = 12, cutoff = 0.05):


    
    #Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC', maxlag = 20 )
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    pvalue = dftest[1]
    if pvalue < cutoff:
        print('p-value = %.4f. The series is likely stationary.' % pvalue)
    else:
        print('p-value = %.4f. The series is likely non-stationary.' % pvalue)
    
    print(dfoutput)

# %%
test_stationarity(df['Revenue'])
# Out:
# Results of Dickey-Fuller Test:
# p-value = 0.1997. The series is likely non-stationary.
# Test Statistic                  -2.218319
# p-value                          0.199664
# #Lags Used                       1.000000
# Number of Observations Used    729.000000
# Critical Value (1%)             -3.439352
# Critical Value (5%)             -2.865513
# Critical Value (10%)            -2.568886
# dtype: float64

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
result = seasonal_decompose(df['Revenue'], model='additive', period=12)

# %%
result.seasonal.plot()
# Out:
# <AxesSubplot:>

# %%
result.trend.plot()
# Out:
# <AxesSubplot:>

# %%
#decompose time series
result.resid.plot()
# Out:
# <AxesSubplot:>

# %%
fig = plt.figure()  
fig = result.plot()  
fig.set_size_inches(15, 12)

# %%
#Make 'Day' column into a datetime object and set as index
import datetime as dt
from datetime import datetime

day1 = dt.datetime.today()
#must specify 1 day extra to account for Day 0 being index
date_list = [day1 + dt.timedelta(days=x) for x in range(731)]

# %%
df['Date'] = date_list
df.head()
# Out:
#    Day   Revenue                       Date
# 0    1  0.000000 2023-03-08 14:06:30.793687
# 1    2 -0.292356 2023-03-09 14:06:30.793687
# 2    3 -0.327772 2023-03-10 14:06:30.793687
# 3    4 -0.339987 2023-03-11 14:06:30.793687
# 4    5 -0.124888 2023-03-12 14:06:30.793687

# %%
df['Date'] = pd.to_datetime(df['Date']).dt.date
df = df.set_index(['Date'])
df.head()
# Out:
#             Day   Revenue
# Date
# 2023-03-08    1  0.000000
# 2023-03-09    2 -0.292356
# 2023-03-10    3 -0.327772
# 2023-03-11    4 -0.339987
# 2023-03-12    5 -0.124888

# %%
del df['Day']
df.head()
# Out:
#              Revenue
# Date
# 2023-03-08  0.000000
# 2023-03-09 -0.292356
# 2023-03-10 -0.327772
# 2023-03-11 -0.339987
# 2023-03-12 -0.124888

# %%
df.to_csv(r'C:\Users\dre2\Desktop\WGU\D213\cleaned.csv')

# %%
from scipy import signal
f, Pxx_den = signal.periodogram(df['Revenue'])
plt.semilogy(f, Pxx_den)
plt.ylim([1e-6, 1e2])
plt.title("Spectral Density")
plt.xlabel('Frequency')
plt.ylabel('Spectral Density')
plt.show()

# %%
pip install pmdarima
# Out:
# Collecting pmdarima
#   Using cached pmdarima-2.0.2-cp38-cp38-win_amd64.whl (571 kB)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\dre2\anaconda3\anaconda3_reinstall\lib\site-packages (from pmdarima) (0.29.23)
# Requirement already satisfied: joblib>=0.11 in c:\users\dre2\anaconda3\anaconda3_reinstall\lib\site-packages (from pmdarima) (1.0.1)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\dre2\anaconda3\anaconda3_reinstall\lib\site-packages (from pmdarima) (0.24.1)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\dre2\anaconda3\anaconda3_reinstall\lib\site-packages (from pmdarima) (52.0.0.post20210125)
# Requirement already satisfied: urllib3 in c:\users\dre2\anaconda3\anaconda3_reinstall\lib\site-packages (from pmdarima) (1.26.4)
# Collecting statsmodels>=0.13.2
#   Using cached statsmodels-0.13.5-cp38-cp38-win_amd64.whl (9.2 MB)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\dre2\anaconda3\anaconda3_reinstall\lib\site-packages (from pmdarima) (1.22.4)
# Requirement already satisfied: pandas>=0.19 in c:\users\dre2\anaconda3\anaconda3_reinstall\lib\site-packages (from pmdarima) (1.2.4)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\dre2\anaconda3\anaconda3_reinstall\lib\site-packages (from pmdarima) (1.6.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\dre2\anaconda3\anaconda3_reinstall\lib\site-packages (from pandas>=0.19->pmdarima) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\dre2\anaconda3\anaconda3_reinstall\lib\site-packages (from pandas>=0.19->pmdarima) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\dre2\anaconda3\anaconda3_reinstall\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.19->pmdarima) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\dre2\anaconda3\anaconda3_reinstall\lib\site-packages (from scikit-learn>=0.22->pmdarima) (2.1.0)
# Collecting packaging>=21.3
#   Using cached packaging-23.0-py3-none-any.whl (42 kB)
# Collecting patsy>=0.5.2
#   Using cached patsy-0.5.3-py2.py3-none-any.whl (233 kB)
# Installing collected packages: patsy, packaging, statsmodels, pmdarima
#   Attempting uninstall: patsy
#     Found existing installation: patsy 0.5.1
#     Uninstalling patsy-0.5.1:
#       Successfully uninstalled patsy-0.5.1
#   Attempting uninstall: packaging
#     Found existing installation: packaging 20.9
#     Uninstalling packaging-20.9:
#       Successfully uninstalled packaging-20.9
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.12.2
#     Uninstalling statsmodels-0.12.2:
#       Successfully uninstalled statsmodels-0.12.2
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\dre2\\anaconda3\\anaconda3_reinstall\\Lib\\site-packages\\~tatsmodels\\tsa\\kalmanf\\kalman_loglike.cp38-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.

# %%
df.head()
# Out:
#              Revenue
# Date
# 2023-03-08  0.000000
# 2023-03-09 -0.292356
# 2023-03-10 -0.327772
# 2023-03-11 -0.339987
# 2023-03-12 -0.124888

# %%
import pmdarima as pm
from pmdarima import model_selection
from pmdarima.arima import auto_arima
from pmdarima.model_selection import train_test_split
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-24-32bb690695d9> in <module>
# ----> 1 import pmdarima as pm
#       2 from pmdarima import model_selection
#       3 from pmdarima.arima import auto_arima
#       4 from pmdarima.model_selection import train_test_split
#
# ModuleNotFoundError: No module named 'pmdarima'

# %%
train=df[:530]
test=df[-201:]
plt.plot(train)
plt.plot(test)

# %%
model=auto_arima(train,start_p=0,d=1,start_q=0,
          max_p=5,max_d=5,max_q=5, start_P=0,
          D=1, start_Q=0, max_P=5,max_D=5,
          max_Q=5, m=90, seasonal=True,
          error_action='warn',trace=True,
          supress_warnings=True,stepwise=True,
          random_state=20,n_fits=50)

# %%
model.summary()

# %%
prediction = pd.DataFrame(model.predict(n_periods = 201),index=test.index)
prediction.columns = ['Predicted Revenue']
plt.figure(figsize=(10,5))
plt.plot(train,label="Training")
plt.plot(test,label="Test")
plt.plot(prediction,label="Predicted")
plt.legend(loc = 'upper left')
plt.show()

# %%
model.plot_diagnostics()
